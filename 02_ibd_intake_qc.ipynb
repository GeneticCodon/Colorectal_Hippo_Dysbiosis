# %% [markdown]
# # 02 · IBD intake & QC
# Loads GSE235236 counts + metadata via manifest and prints basic stats.

# %%
from pathlib import Path
import pandas as pd
BASE = "/content/drive/MyDrive/Colorectal_Hippo_Dysbiosis"
man = pd.read_csv(f"{BASE}/config/manifest_ibd.csv").set_index("key")["path"].to_dict()

counts = pd.read_csv(man["counts"], sep=None, engine="python")
meta = pd.read_csv(man["metadata"])
print("IBD counts shape:", counts.shape)
print("IBD metadata shape:", meta.shape)

# Simple label check (adjust column name if needed)
candidate_cols = [c for c in meta.columns if c.lower() in ["group","status","condition","phenotype","disease","diagnosis"]]
print("Candidate group columns:", candidate_cols)

meta.to_csv(f"{BASE}/results/qc/ibd_metadata_snapshot.csv", index=False)
print("Saved IBD metadata snapshot.")
